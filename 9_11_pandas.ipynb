# %% [markdown]
# <a href="https://colab.research.google.com/github/Leetora41053/sessac_python/blob/main/9_11_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.pandas

# %% [markdown]
# ## Series

# %%
import pandas as pd
prices = [1000, 1010, 1020]
Series1= pd.Series(prices)
Series1

#index - value 관계의 테이블
# Out:
# 0    1000
# 1    1010
# 2    1020
# dtype: int64

# %%
#date_range함수: 날짜 인덱스를 생성. 1월1일 부터 3개 생성해달라
dates= pd.date_range('20230101', periods = 3)

#dates로 된 인덱스를 추가
Series2 = pd.Series(prices, index = dates)
Series2
# Out:
# 2023-01-01    1000
# 2023-01-02    1010
# 2023-01-03    1020
# Freq: D, dtype: int64

# %%
#날짜 frequency를 조정해주는 함수 - month (default 월말)
pd.date_range('2022-01-01', '2023-01-01', freq ='M')

#날짜 frequency를 조정해주는 함수 - month start
pd.date_range('2022-01-01', '2023-01-01', freq ='MS')
# Out:
# DatetimeIndex(['2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
#새로운 row를 삽입하고 싶을 때에도 가능
Series2['2023-01-04'] = 1030
Series2
# Out:
# 2023-01-01    1000
# 2023-01-02    1010
# 2023-01-03    1020
# 2023-01-04    1030
# Freq: D, dtype: int64

# %%
#슬라이싱을 통해 원하는 값을 출력할 수 있음
Series2[1:3]
# Out:
# 2023-01-02    1010
# 2023-01-03    1020
# Freq: D, dtype: int64

# %%
#숫자 하나만 기입할 시 값만 출력된다
Series2[2]
# Out:
# 1020

# %%
#인덱스를 입력해 값을 추출할 수도 있음
Series2['2023-01-03']
# Out:
# 1020

# %%
#데이터의 특정 값을 수정할 수도 있음
Series2[2]= 1080
Series2

# %% [markdown]
# ## DataFrame

# %%
#딕셔너리 key - value(리스트)로 테이블 형태로 추출

prices = {
    'SK텔레콤': [44000, 44500, 4500],
    '삼성전자': [70100, 70200, 70300],
    'LG전자': [85000,85500, 86000]
}

df1 = pd.DataFrame(prices)
df1

# %%
#날짜 데이터를 인덱스로 삽입하기
df2 = pd.DataFrame(prices, index = dates)
df2
# Out:
#             SK텔레콤   삼성전자   LG전자
# 2023-01-01  44000  70100  85000
# 2023-01-02  44500  70200  85500
# 2023-01-03   4500  70300  86000

# %% [markdown]
# ### 데이터 선택
# **- loc(label location): index, column으로 데이터를 가져온다**
# </br>
# **- iloc(integer location): 데이터 순서로 데이터를 가져온다**

# %%
#row가 선택되는 데이터
df2.iloc[0]
# Out:
# SK텔레콤    44000
# 삼성전자     70100
# LG전자     85000
# Name: 2023-01-01 00:00:00, dtype: int64

# %%
#0번째 데이터 전부를 가져오고 싶다면?
#row는 전체 다 , column은 0번째
df2.iloc[:,0]
# Out:
# 2023-01-01    44000
# 2023-01-02    44500
# 2023-01-03     4500
# Freq: D, Name: SK텔레콤, dtype: int64

# %%
#SK의 44000원을 갖고 오고 싶다면?
df2.iloc[0,0]
# Out:
# 44000

# %%
#index, column데이터를 가져오는 loc
df2.loc['2023-01-02']
# Out:
# SK텔레콤    44500
# 삼성전자     70200
# LG전자     85500
# Name: 2023-01-02 00:00:00, dtype: int64

# %%
#index 전체 다, column은 SK텔레콤만 원할 때
df2.loc[:,'SK텔레콤']
# Out:
# 2023-01-01    44000
# 2023-01-02    44500
# 2023-01-03     4500
# Freq: D, Name: SK텔레콤, dtype: int64

# %%
#칼럼 확인하는 두 가지 방법
df2['SK텔레콤']
df2.SK텔레콤
# Out:
# 2023-01-01    44000
# 2023-01-02    44500
# 2023-01-03     4500
# Freq: D, Name: SK텔레콤, dtype: int64

# %%
#key - value를 새로 삽입
#column 갯수를 동일하게 삽입해야 함
df2['POSCO'] = [450000, 455000, 460000]
df2
# Out:
#             SK텔레콤   삼성전자   LG전자   POSCO
# 2023-01-01  44000  70100  85000  450000
# 2023-01-02  44500  70200  85500  455000
# 2023-01-03   4500  70300  86000  460000

# %% [markdown]
# **실습**
# Q1. 2023년 1월 2일 ~ 2023 1월 3일 까지의 '삼성전자', 'LG전자' 데이터를 가져와주세요.

# %%
df2.iloc[1:3, 1:3]
df2.loc['2023-01-02':'2023-01-04','삼성전자']
df2.loc['2023-01-02':'2023-01-04','LG전자']
# Out:
# 2023-01-02    85500
# 2023-01-03    86000
# Freq: D, Name: LG전자, dtype: int64

# %%
df2.loc['2023-01-02':, '삼성전자':'LG전자']
# Out:
#              삼성전자   LG전자
# 2023-01-02  70200  85500
# 2023-01-03  70300  86000

# %% [markdown]
# **실습**
# Q2. 데이터 70200원 가져오기 (iloc, loc 각각 활용)

# %%
df2.loc['2023-01-02','삼성전자']
df2.iloc[1,1]
# Out:
# 70200

# %% [markdown]
# ### 데이터프레임 확장
# - concat : 그냥 가져다 붙이는 거
#     - 행을 덧붙일 때
#     - 열을 덧붙일 때
# - merge : 공통된 칼럼이나 인덱스가 있는 경우 붙이는 거

# %%
#시리즈로 테이블에 추가
s1 = pd.Series([500000, 500500, 501000], index = dates, name= 'LG화학')
#concat으로 열추가
concat_df2 = pd.concat([df2,s1] , axis = 1)
concat_df2
# Out:
#             SK텔레콤   삼성전자   LG전자   POSCO    LG화학
# 2023-01-01  44000  70100  85000  450000  500000
# 2023-01-02  44500  70200  85500  455000  500500
# 2023-01-03   4500  70300  86000  460000  501000

# %%
#for문을 거치지 않고도 시리즈 형태로 column추가
concat_df2['LG화학_add_500'] = concat_df2['LG화학'] + 500
concat_df2
# Out:
#             SK텔레콤   삼성전자   LG전자   POSCO    LG화학  LG화학_add_500
# 2023-01-01  44000  70100  85000  450000  500000        500500
# 2023-01-02  44500  70200  85500  455000  500500        501000
# 2023-01-03   4500  70300  86000  460000  501000        501500

# %%
concat_df2.loc['2023-01-06',:] = [
    44000, 70100, 85000, 455000, 505000, 505500]
concat_df2
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-03   4500.0  70300.0  86000.0  460000.0  501000.0      501500.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0

# %%
concat_df2.loc['2023-01-05',:] = concat_df2.loc['2023-01-06',:] - 100
concat_df2
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-03   4500.0  70300.0  86000.0  460000.0  501000.0      501500.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  504900.0      505400.0

# %% [markdown]
# ### 데이터 정렬

# %%
concat_df2.sort_index()
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-03   4500.0  70300.0  86000.0  460000.0  501000.0      501500.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  504900.0      505400.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0

# %%
#기준을 삼고 정렬 / 내림차순
concat_df2.sort_values(by = '삼성전자', ascending = False)
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-03   4500.0  70300.0  86000.0  460000.0  501000.0      501500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  504900.0      505400.0

# %%
#기준을 삼고 정렬 / 오름차순
concat_df2.sort_values(by = '삼성전자')
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  504900.0      505400.0
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-03   4500.0  70300.0  86000.0  460000.0  501000.0      501500.0

# %% [markdown]
# #데이터 삭제

# %%
#특정 row 데이터를 삭제
concat_df2.drop('2023-01-03')
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  504900.0      505400.0

# %%
#inplace를 통한 삭제
concat_df2.drop('2023-01-03', inplace = True)
concat_df2

#하지만 두 번 쓸 때가 되면 오류가 뜸

# %%
#특정 column을 삭제하고 싶을 때
concat_df2.drop('LG화학', axis = 1)
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO  LG화학_add_500
# 2023-01-01  44000.0  70100.0  85000.0  450000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0      505500.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0      505400.0

# %%
#다수의 열을 삭제하고 싶을 때
concat_df2.drop(['LG화학','LG화학_add_500'], axis = 1)
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO
# 2023-01-01  44000.0  70100.0  85000.0  450000.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0

# %% [markdown]
# ## 데이터프레임 다루기

# %%
#모든 항목의 주가 총 합
concat_df2['sum'] = concat_df2.sum(axis = 1)
concat_df2
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  504900.0      505400.0
#
#                   sum
# 2023-01-01  3299200.0
# 2023-01-02  3313400.0
# 2023-01-06  3329200.0
# 2023-01-05  3328000.0

# %%
#종목 별 최저가를 구하는 법 / axis = 0이 디폴트
concat_df2.min(axis = 0)
# Out:
# SK텔레콤             43900.0
# 삼성전자              70000.0
# LG전자              84900.0
# POSCO            450000.0
# LG화학             500000.0
# LG화학_add_500     500500.0
# sum             3299200.0
# dtype: float64

# %%
#문자열은 제외, 숫자열로 된 것에 대해 통계적 정리를 해주는 함수
concat_df2.describe()
# Out:
#              SK텔레콤          삼성전자         LG전자         POSCO           LG화학  \
# count      4.00000      4.000000      4.00000       4.00000       4.000000
# mean   44100.00000  70100.000000  85100.00000  453725.00000  502600.000000
# std      270.80128     81.649658    270.80128    2483.78072    2721.519184
# min    43900.00000  70000.000000  84900.00000  450000.00000  500000.000000
# 25%    43975.00000  70075.000000  84975.00000  453675.00000  500375.000000
# 50%    44000.00000  70100.000000  85000.00000  454950.00000  502700.000000
# 75%    44125.00000  70125.000000  85125.00000  455000.00000  504925.000000
# max    44500.00000  70200.000000  85500.00000  455000.00000  505000.000000
#
#         LG화학_add_500           sum
# count       4.000000  4.000000e+00
# mean   503100.000000  3.317450e+06
# std      2721.519184  1.412834e+04
# min    500500.000000  3.299200e+06
# 25%    500875.000000  3.309850e+06
# 50%    503200.000000  3.320700e+06
# 75%    505425.000000  3.328300e+06
# max    505500.000000  3.329200e+06

# %% [markdown]
# ## 결측치 처리
# - 제거: dropna
# - 대체: fillna, interpolate

# %%
# inplace = True : 변수 설정을 굳이 안해줘도 된다
# 인덱스 분류
concat_df2.sort_index(inplace = True)

# %%
#빈값만들기
import numpy as np
concat_df2.loc['2023-01-05', "LG전자":'LG화학']= np.NaN
concat_df2

#제거 / 대체 어떤 것을 써야할까? -> 상황 마다 다르기 때문에 데이터의 흐름에 따라 변경해야 함
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      505400.0
#
#                   sum
# 2023-01-01  3299200.0
# 2023-01-02  3313400.0
# 2023-01-06  3329200.0
# 2023-01-05  3328000.0

# %%
#dropna: NaN 값을 다 날리기 - row
concat_df2.dropna()
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
#
#                   sum
# 2023-01-01  3299200.0
# 2023-01-02  3313400.0
# 2023-01-06  3329200.0

# %%
#대체 - fillna: 앞 값으로 빈 값을 채워주는 방법
concat_df2.fillna(method='ffill')
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0  85000.0  455000.0  505000.0      505400.0
#
#                   sum
# 2023-01-01  3299200.0
# 2023-01-02  3313400.0
# 2023-01-06  3329200.0
# 2023-01-05  3328000.0

# %%
#대체 - fillna: 뒷 값으로 빈 값을 채워주는 방법
concat_df2.fillna(method='bfill')
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      505400.0
#
#                   sum
# 2023-01-01  3299200.0
# 2023-01-02  3313400.0
# 2023-01-06  3329200.0
# 2023-01-05  3328000.0

# %%
#대체 - interpolate: 중간 값으로 시계열을 삽입
concat_df2.interpolate()
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0  85000.0  455000.0  505000.0      505400.0
#
#                   sum
# 2023-01-01  3299200.0
# 2023-01-02  3313400.0
# 2023-01-06  3329200.0
# 2023-01-05  3328000.0

# %% [markdown]
# ##중복제거

# %%
#고의적 중첩 발생
concat_df3 = concat_df2.copy()
concat_df4 = pd.concat([concat_df2, concat_df3])
concat_df4
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      505400.0
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      505400.0
#
#                   sum
# 2023-01-01  3299200.0
# 2023-01-02  3313400.0
# 2023-01-06  3329200.0
# 2023-01-05  3328000.0
# 2023-01-01  3299200.0
# 2023-01-02  3313400.0
# 2023-01-06  3329200.0
# 2023-01-05  3328000.0

# %%
#drop_duplicates: 중복 제거
concat_df4.drop_duplicates()
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      505400.0
#
#                   sum
# 2023-01-01  3299200.0
# 2023-01-02  3313400.0
# 2023-01-06  3329200.0
# 2023-01-05  3328000.0

# %%
concat_df2.loc['2023-01-03',:] = concat_df2.loc['2023-01-06',:].copy()
concat_df2.sort_index(inplace = True)

concat_df2
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-03  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      505400.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
#
#                   sum
# 2023-01-01  3299200.0
# 2023-01-02  3313400.0
# 2023-01-03  3329200.0
# 2023-01-05  3328000.0
# 2023-01-06  3329200.0

# %%
#응용 연습 - 삼성전자의 중복만 제거하여 데이터프레임 형태로 출력

idx = concat_df2['삼성전자'].drop_duplicates().index

concat_df2.loc[idx,:]
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-05'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### 실습

# %%
#dropna: NaN 값을 다 날리기 - column
concat_df2.dropna(axis = 1)
# Out:
#               SK텔레콤     삼성전자  LG화학_add_500        sum
# 2023-01-01  44000.0  70100.0      500500.0  3299200.0
# 2023-01-02  44500.0  70200.0      501000.0  3313400.0
# 2023-01-06  44000.0  70100.0      505500.0  3329200.0
# 2023-01-05  43900.0  70000.0      505400.0  3328000.0

# %% [markdown]
# Q1. 2022-01-01 ~ 2022-12-01 월초 인덱스를 생성<br>
# Q2. Q1에서 생성한 인덱스를 가지고 데이터프레임 생성(값은 자율, 이때 칼럼이름은 value)<br>
# Q3. value 칼럼에서 100을 더한 value_add_100 칼럼을 생성해주세요.<br>
# Q4. value 칼럼과 value_add_100 칼럼을 평균한 mean 칼럼을 생성해주세요.<br>

# %%
#1
exam_df1 = pd.date_range('2022-01-01', '2022-12-01', freq ='MS')
exam_df1
# Out:
# DatetimeIndex(['2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
#2
# Out:
#    SK텔레콤   삼성전자   LG전자
# 0  44000  70100  85000
# 1  44500  70200  85500
# 2   4500  70300  86000
